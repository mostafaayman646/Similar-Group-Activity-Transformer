# %% [markdown]
# # Loading libraries

# %%
import json
import pandas as pd

# %% [markdown]
# # Changing Setting of pandas to get full rows

# %%
# Set no limit for rows
pd.set_option('display.max_rows', None)

# Set no limit for columns
pd.set_option('display.max_columns', None)

# Show up to 500 characters per cell
pd.set_option('display.max_colwidth', 500)

# Show the full content regardless of length
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Load Event Data

# %%
# 1. Load Event Data (JSON)
with open('../FIFA World Cup 2022/Event Data/10510.json', 'rt') as f:
    events_data = json.load(f)

events_df = pd.DataFrame(events_data)

# %%
events_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3160 entries, 0 to 3159
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gameId             3160 non-null   int64
#  1   gameEventId        3160 non-null   int64
#  2   possessionEventId  1917 non-null   float64
#  3   startTime          3160 non-null   float64
#  4   endTime            3032 non-null   float64
#  5   duration           3160 non-null   float64
#  6   eventTime          3160 non-null   float64
#  7   sequence           3018 non-null   float64
#  8   gameEvents         3160 non-null   object
#  9   initialTouch       3160 non-null   object
#  10  possessionEvents   3160 non-null   object
#  11  fouls              3160 non-null   object
#  12  grades             3160 non-null   object
#  13  stadiumMetadata    3160 non-null   object
#  14  homePlayers        3160 non-null   object
#  15  awayPlayers        3160 non-null   object
# ...

# %%
print(events_df['gameId'][:5])
print(events_df['gameId'].nunique())
print(events_df['gameId'].isna().sum())
# Out:
# 0    10510
# 1    10510
# 2    10510
# 3    10510
# 4    10510
# Name: gameId, dtype: int64
# 1
# 0

# %%
print(events_df['gameEventId'][:5])
print(events_df['gameEventId'].nunique())
print(events_df['gameEventId'].isna().sum())
# Out:
# 0    6662332
# 1    6662335
# 2    6662335
# 3    6662337
# 4    6662341
# Name: gameEventId, dtype: int64
# 1927
# 0

# %%
print(events_df['possessionEventId'][:5])
print(events_df['possessionEventId'].nunique())
print(events_df['possessionEventId'].isna().sum())
# Out:
# 0    6545591.0
# 1          NaN
# 2    6545595.0
# 3    6545597.0
# 4          NaN
# Name: possessionEventId, dtype: float64
# 1917
# 1243

# %%
print(events_df['startTime'][:5])
print(events_df['startTime'].isna().sum())
# Out:
# 0    180.314
# 1    181.215
# 2    181.215
# 3    182.883
# 4    184.751
# Name: startTime, dtype: float64
# 0

# %%
print(events_df['endTime'][:5])
print(events_df['endTime'].isna().sum())
# Out:
# 0    180.314
# 1    182.182
# 2    182.182
# 3    182.883
# 4    185.853
# Name: endTime, dtype: float64
# 128

# %%
print(events_df['duration'][:5])
print(events_df['duration'].isna().sum())
# Out:
# 0    0.000
# 1    0.967
# 2    0.967
# 3    0.000
# 4    1.102
# Name: duration, dtype: float64
# 0

# %%
print(events_df['eventTime'][:5])
print(events_df['eventTime'].isna().sum())
# Out:
# 0    180.314
# 1    181.215
# 2    182.182
# 3    182.883
# 4    184.751
# Name: eventTime, dtype: float64
# 0

# %%
print(events_df['sequence'][:5])        # Sequence ID
print(events_df['sequence'].nunique())
print(events_df['sequence'].iloc[-2])
print(events_df['sequence'].isna().sum())
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: sequence, dtype: float64
# 315
# 315.0
# 142

# %%
expanded_events_df = pd.json_normalize(events_df['gameEvents'])
for item in expanded_events_df.columns.tolist():
    print(f"{item}: {expanded_events_df[item].isna().sum()}")
# Out:
# gameEventType: 0
# initialNonEvent: 0
# startGameClock: 0
# startFormattedGameClock: 0
# period: 0
# videoMissing: 0
# teamId: 152
# teamName: 152
# homeTeam: 152
# playerId: 152
# playerName: 152
# touches: 153
# touchesInBox: 142
# setpieceType: 142
# earlyDistribution: 142
# videoUrl: 0
# endType: 3156
# outType: 3033
# subType: 3150
# playerOffId: 3150
# playerOffName: 3150
# playerOffType: 3160
# playerOnId: 3150
# playerOnName: 3150

# %%
events_df['gameEvents'][0]
# Out:
# {'gameEventType': 'FIRSTKICKOFF',
#  'initialNonEvent': False,
#  'startGameClock': 0,
#  'startFormattedGameClock': '00:00',
#  'period': 1,
#  'videoMissing': False,
#  'teamId': 371,
#  'teamName': 'Croatia',
#  'homeTeam': True,
#  'playerId': 1687,
#  'playerName': 'Luka Modric',
#  'touches': 1,
#  'touchesInBox': 0,
#  'setpieceType': 'K',
#  'earlyDistribution': False,
#  'videoUrl': 'https://epitome.pff.com/en/film_room/ae543588-0724-455a-9f43-e912762c131e/180.314',
#  'endType': None,
#  'outType': None,
#  'subType': None,
#  'playerOffId': None,
#  'playerOffName': None,
#  'playerOffType': None,
#  'playerOnId': None,
#  'playerOnName': None}

# %%
expanded_events_df = pd.json_normalize(events_df['initialTouch'])
for item in expanded_events_df.columns.tolist():
    print(f"{item}: {expanded_events_df[item].isna().sum()}")
# Out:
# initialBodyType: 0
# initialHeightType: 0
# facingType: 0
# initialTouchType: 142
# initialPressureType: 142
# initialPressurePlayerId: 2660
# initialPressurePlayerName: 2660

# %%
events_df['initialTouch'][0]
# Out:
# {'initialBodyType': 'R',
#  'initialHeightType': 'G',
#  'facingType': 'G',
#  'initialTouchType': 'S',
#  'initialPressureType': 'N',
#  'initialPressurePlayerId': None,
#  'initialPressurePlayerName': None}

# %%
expanded_events_df = pd.json_normalize(events_df['possessionEvents'])
for item in expanded_events_df.columns.tolist():
    print(f"{item}: {expanded_events_df[item].isna().sum()}")
# Out:
# possessionEventType: 149
# nonEvent: 1243
# gameClock: 149
# formattedGameClock: 149
# eventVideoUrl: 149
# ballHeightType: 1589
# bodyType: 1531
# highPointType: 1570
# passerPlayerId: 1733
# passerPlayerName: 1733
# passType: 1733
# passOutcomeType: 1733
# crosserPlayerId: 3112
# crosserPlayerName: 3112
# crossType: 3112
# crossZoneType: 3112
# crossOutcomeType: 3112
# targetPlayerId: 1696
# targetPlayerName: 1696
# targetFacingType: 1733
# receiverPlayerId: 1884
# receiverPlayerName: 1884
# receiverFacingType: 1903
# defenderPlayerId: 3021
# defenderPlayerName: 3021
# blockerPlayerId: 3115
# blockerPlayerName: 3115
# deflectorPlayerId: 3153
# deflectorPlayerName: 3153
# failedBlockerPlayerId: 3017
# failedBlockerPlayerName: 3017
# failedBlocker2PlayerId: 3157
# failedBlocker2PlayerName: 3157
# accuracyType: 1884
# incompletionReasonType: 2958
# secondIncompletionReasonType: 3085
# linesBrokenType: 3031
# shooterPlayerId: 3121
# shooterPlayerName: 3121
# bodyMovementType: 3121
# ...

# %%
events_df['possessionEvents'][0]
# Out:
# {'possessionEventType': 'PA',
#  'nonEvent': False,
#  'gameClock': 0,
#  'formattedGameClock': '00:00',
#  'eventVideoUrl': 'https://epitome.pff.com/en/film_room/ae543588-0724-455a-9f43-e912762c131e/180.314',
#  'ballHeightType': 'G',
#  'bodyType': 'R',
#  'highPointType': 'G',
#  'passerPlayerId': 1687,
#  'passerPlayerName': 'Luka Modric',
#  'passType': 'S',
#  'passOutcomeType': 'C',
#  'crosserPlayerId': None,
#  'crosserPlayerName': None,
#  'crossType': None,
#  'crossZoneType': None,
#  'crossOutcomeType': None,
#  'targetPlayerId': 8129,
#  'targetPlayerName': 'Marcelo Brozovic',
#  'targetFacingType': 'G',
#  'receiverPlayerId': 8129,
#  'receiverPlayerName': 'Marcelo Brozovic',
#  'receiverFacingType': 'G',
#  'defenderPlayerId': None,
#  'defenderPlayerName': None,
#  'blockerPlayerId': None,
#  'blockerPlayerName': None,
#  'deflectorPlayerId': None,
#  'deflectorPlayerName': None,
#  'failedBlockerPlayerId': None,
#  'failedBlockerPlayerName': None,
# ...

# %%
expanded_events_df = pd.json_normalize(events_df['fouls'])
for item in expanded_events_df.columns.tolist():
    print(f"{item}: {expanded_events_df[item].isna().sum()}")
# Out:
# onFieldCulpritPlayerId: 3101
# onFieldCulpritPlayerName: 3101
# finalCulpritPlayerId: 3101
# finalCulpritPlayerName: 3101
# victimPlayerId: 3111
# victimPlayerName: 3111
# foulType: 3101
# onFieldOffenseType: 3101
# finalOffenseType: 3101
# onFieldFoulOutcomeType: 3101
# finalFoulOutcomeType: 3101
# var: 3101
# varReasonType: 3160
# correctDecision: 3101

# %%
expanded_events_df = pd.json_normalize(events_df['grades'])
for item in expanded_events_df.columns.tolist():
    print(f"{item}: {expanded_events_df[item].isna().sum()}")
# Out:
# additionalDuelerGrade: 3159
# awayDuelGrade: 3085
# ballCarrierGrade: 3149
# blockerGrade: 3115
# carrierGrade: 3029
# carryDefenderGrade: 3149
# challengerGrade: 2977
# clearerGrade: 3102
# closingDownGrade: 3158
# crosserGrade: 3112
# dabGrade: 3158
# defenderGrade: 3021
# deflectorGrade: 3153
# disciplineGrade: 3159
# dribblerGrade: 3108
# failedBlockerGrade: 3017
# failedBlocker2Grade: 3157
# homeDuelGrade: 3085
# keeperGrade: 3139
# movementGrade: 3156
# passerGrade: 1733
# positionGrade: 3143
# receiverGrade: 1884
# shooterGrade: 3121
# targetGrade: 2990
# touchGrade: 3134

# %%
expanded_events_df = pd.json_normalize(events_df['stadiumMetadata'])
for item in expanded_events_df.columns.tolist():
    print(f"{item}: {expanded_events_df[item].isna().sum()}")
# Out:
# stadiumId: 0
# stadiumName: 0
# pitchLength: 0
# pitchWidth: 0
# homeTeamStartLeft: 0
# homeTeamStartLeftExtraTime: 0
# teamAttackingDirection: 0

# %%
events_df['stadiumMetadata'][0]
# Out:
# {'stadiumId': 189,
#  'stadiumName': 'Education City Stadium',
#  'pitchLength': 105.0,
#  'pitchWidth': 68.0,
#  'homeTeamStartLeft': True,
#  'homeTeamStartLeftExtraTime': True,
#  'teamAttackingDirection': 'R'}

# %%
exploded_players = events_df['homePlayers'].explode()

expanded_events_df = pd.json_normalize(exploded_players)

for item in expanded_events_df.columns.tolist():
    print(f"{item}: {expanded_events_df[item].isna().sum()}")
# Out:
# jerseyNum: 0
# confidence: 0
# visibility: 0
# x: 0
# y: 0
# speed: 0
# playerId: 0
# positionGroupType: 0

# %%
events_df['homePlayers'][0]
# Out:
# [{'jerseyNum': 8,
#   'confidence': 'HIGH',
#   'visibility': 'VISIBLE',
#   'x': -3.391,
#   'y': 10.422,
#   'speed': 0.084,
#   'playerId': 100,
#   'positionGroupType': 'CM'},
#  {'jerseyNum': 1,
#   'confidence': 'LOW',
#   'visibility': 'ESTIMATED',
#   'x': -39.639,
#   'y': 0.237,
#   'speed': 0.504,
#   'playerId': 13854,
#   'positionGroupType': 'GK'},
#  {'jerseyNum': 22,
#   'confidence': 'HIGH',
#   'visibility': 'VISIBLE',
#   'x': -0.149,
#   'y': -28.143,
#   'speed': 0.694,
#   'playerId': 13858,
#   'positionGroupType': 'RB'},
#  {'jerseyNum': 10,
#   'confidence': 'HIGH',
#   'visibility': 'VISIBLE',
#   'x': 0.291,
#   'y': 0.283,
#   'speed': 0.568,
#   'playerId': 1687,
#   'positionGroupType': 'CM'},
#  {'jerseyNum': 6,
#   'confidence': 'LOW',
#   'visibility': 'ESTIMATED',
#   'x': -16.693,
#   'y': -6.774,
#   'speed': 0.777,
#   'playerId': 40,
#   'positionGroupType': 'RCB'},
#  {'jerseyNum': 9,
#   'confidence': 'HIGH',
#   'visibility': 'VISIBLE',
# ...

# %%
exploded_players = events_df['awayPlayers'].explode()

expanded_events_df = pd.json_normalize(exploded_players)

for item in expanded_events_df.columns.tolist():
    print(f"{item}: {expanded_events_df[item].isna().sum()}")
# Out:
# jerseyNum: 0
# confidence: 0
# visibility: 0
# x: 0
# y: 0
# speed: 0
# playerId: 0
# positionGroupType: 0

# %%
events_df['awayPlayers'][0]
# Out:
# [{'jerseyNum': 14,
#   'confidence': 'LOW',
#   'visibility': 'ESTIMATED',
#   'x': 19.358,
#   'y': 10.664,
#   'speed': 1.048,
#   'playerId': 1676,
#   'positionGroupType': 'RB'},
#  {'jerseyNum': 5,
#   'confidence': 'LOW',
#   'visibility': 'ESTIMATED',
#   'x': 13.53,
#   'y': -5.916,
#   'speed': 1.293,
#   'playerId': 1683,
#   'positionGroupType': 'CM'},
#  {'jerseyNum': 20,
#   'confidence': 'LOW',
#   'visibility': 'VISIBLE',
#   'x': 9.429,
#   'y': -10.661,
#   'speed': 0.015,
#   'playerId': 1695,
#   'positionGroupType': 'LW'},
#  {'jerseyNum': 3,
#   'confidence': 'LOW',
#   'visibility': 'ESTIMATED',
#   'x': 18.907,
#   'y': -5.678,
#   'speed': 0.889,
#   'playerId': 1926,
#   'positionGroupType': 'LCB'},
#  {'jerseyNum': 9,
#   'confidence': 'LOW',
#   'visibility': 'VISIBLE',
#   'x': 2.112,
#   'y': 9.757,
#   'speed': 0.943,
#   'playerId': 195,
#   'positionGroupType': 'CF'},
#  {'jerseyNum': 11,
#   'confidence': 'LOW',
#   'visibility': 'ESTIMATED',
# ...

# %%
exploded_players = events_df['ball'].explode()

expanded_events_df = pd.json_normalize(exploded_players)

for item in expanded_events_df.columns.tolist():
    print(f"{item}: {expanded_events_df[item].isna().sum()}")
# Out:
# visibility: 222
# x: 222
# y: 222
# z: 222

# %%
events_df['ball'][0]
# Out:
# [{'visibility': 'VISIBLE', 'x': -1.18, 'y': 0.19, 'z': 0.0}]
